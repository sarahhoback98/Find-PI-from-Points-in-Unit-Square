# %%
import random
import sys
from math import pi, sin, cos, sqrt
import matplotlib.pyplot as plt
from __future__ import division
import numpy as np
import numpy
import matplotlib.mlab as mlab
from matplotlib.patches import Circle
import time
import math


x_pts =[]
y_pts =[]
xy_pts =[]
def random_points_generator(x):
    for i in range (x):
        x_points= random.uniform(0, 1)
        y_points= random.uniform(0, 1)
        x_pts.append(x_points)
        y_pts.append(y_points)

# %%
# %%time
random_points_generator(10000)
# Out:
# CPU times: user 11.9 ms, sys: 985 µs, total: 12.8 ms
# Wall time: 12.3 ms

# %%
# %%time
pts= np.column_stack((x_pts, y_pts))
# Out:
# CPU times: user 1.44 ms, sys: 330 µs, total: 1.77 ms
# Wall time: 1.6 ms

# %%
# %%time
plt.plot(pts[:,0], pts[:,1], 'o', alpha=0.5)
# Out:
# CPU times: user 113 ms, sys: 20.5 ms, total: 133 ms
# Wall time: 151 ms

# %%
# %%time
circ = Circle((0, 0), radius = 1)
# Out:
# CPU times: user 548 µs, sys: 164 µs, total: 712 µs
# Wall time: 2.92 ms

# %%
# %%time
def iterations(x):
    random_points_generator(x) 
    pts1= np.column_stack((x_pts, y_pts))
    circ = Circle((0, 0), radius = 1)
    y = 0
    y= x
    counter1=0.0
    counter = 0
    for i in range (y):
        array1 = pts1[i]
        truefalselist1 =[]
        truefalselist1= (circ.contains_point(array1))

        if (sum([truefalselist1])) > 0:
           counter +=1
    counter1= ((counter)/x)*4
    return counter1
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 13.8 µs

# %%
iterations(700)
# Out:
# 3.0685714285714285

# %%
# %%time

difference = list()
def values_for_log(x):
    for i in range (1,x):
        difference_value = abs(iterations(10**i)-math.pi)
        difference.append(difference_value)
        
        

    return difference
# Out:
# CPU times: user 9 µs, sys: 1 µs, total: 10 µs
# Wall time: 14.8 µs

# %%
# %%time
values_for_log(7)
# Out:
# CPU times: user 2min 8s, sys: 2.48 s, total: 2min 10s
# Wall time: 2min 25s
# [0.458407346410207,
#  0.05840734641020706,
#  0.009592653589792999,
#  0.0027926535897933036,
#  0.01071265358979323,
#  0.003924653589792992]

# %%
# %%time
x_axis = list()
for i in range (1,7):
    x_axis.append(10**i)

plt.figure()
plt.plot(x_axis,difference)
plt.xscale('log')
plt.xlabel('Number of Points Used', fontdict=None, labelpad=None)
plt.ylabel('Difference Pi Appromixmation and Real Value of Pi', fontdict=None, labelpad=None)
plt.autoscale(True)
plt.legend(['Approximations as Pi as the # of Darts increases'])
plt.show()
# Out:
# CPU times: user 605 ms, sys: 220 ms, total: 825 ms
# Wall time: 854 ms

# %%
# %%time
time_for_iterations= []
def timevalues_iteration(x):
    for i in range (x):
        start = time.time()
        iterations(10**i)
        end = time.time()
        time_for_iterations.append((end - start))
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 11 µs

# %%
# %%time
timevalues_iteration(7)
# Out:
# CPU times: user 2min, sys: 2.17 s, total: 2min 2s
# Wall time: 2min 7s

# %%
x_axis = list()
for i in range (7):
    x_axis.append(10**i)
plt.figure()
plt.plot(x_axis,time_for_iterations)
plt.xscale('log')
plt.xlabel('Number of Points Used', fontdict=None, labelpad=None)
plt.ylabel('Amount of time in Seconds for each Approximation to be Computed ', fontdict=None, labelpad=None)
plt.autoscale(True)
plt.legend(['Time for Each Iteration'])
plt.show()
